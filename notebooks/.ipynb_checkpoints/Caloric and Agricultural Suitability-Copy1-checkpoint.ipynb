# %% [markdown]
# # Caloric Crop Suitability and Agricultural Suitability

# %% [markdown]
# ##This notebook presents the caloric crop suitability index constructed in [Galor and Özak (2014)](https://ideas.repec.org/p/smu/ecowpa/1407.html) and compares it to the agricultural suitability index of [Rammankutty, Foley, Norman, and McSweeney (2001)](http://www.sage.wisc.edu/atlas/maps.php?datasetid=19&includerelatedlinks=1&dataset=19)

# %% [markdown]
# Additionally, it shows how one can use open source tools, in particular Python, to extract data. In order to do the analysis a working installation of Scientific Python is required and the packages imported below have to be installed also. If needed, follow the installation instructions [here](http://ozak.github.io/CompEcon/) or view [this notebook](http://nbviewer.ipython.org/github/ozak/CompEcon/blob/master/notebooks/IntroPython.ipynb).

# %% [markdown]
# Start by importing the modules to be used.

# %%
from __future__ import division
import sys, os, time
# Math, data
import numpy as np
import pandas as pd
pd.set_option('display.width', 140)
# GIS packages
from rasterstats import zonal_stats
import geopandas as gp
import georasters as gr
import mplleaflet

# %%
# directory with shape files for countries and output directory
try:
   os.listdir("/Users/bizcocho/Desktop")
   drv="/Users/bizcocho/Desktop"
except:
   drv="/Volumes/Mirror RAID"

# %% [markdown]
# ## Post 1500CE data

# %%
drv="/Users/bizcocho/Desktop"
growperiod=drv+"/Geographical_Index/DataOthers/FAO/GAEZ/Agroecological/growingperiod/res01_lgd_crav6190.tif"
growperiod=gr.from_file(growperiod)

# %%
energydir=drv+"/Geographical_Index/DataOthers/FAO/GAEZ/Agroclimatic/energyyield/rain_fed/"
tiffiles=[tiffile for tiffile in os.listdir(energydir) if tiffile.endswith('lo.tif')]
emat=np.zeros((len(tiffiles),growperiod.shape[0],growperiod.shape[1]))

# %%
count=0
for tiffile in tiffiles:
    emat[count,:,:]=gr.from_file(energydir+tiffile).raster.data
    count+=1
emat=np.ma.masked_array(emat,mask=(emat==-9), fill_value=-9.)

# %%
esum=emat.sum(axis=0)
emean=emat.mean(axis=0)

# %%
emean.max()
# Out:
# 3454.2925041668

# %%
plt.matshow(esum)

# %%
plt.matshow(emean)

# %%
esum= gr.GeoRaster(esum, growperiod.geot, projection=growperiod.projection, nodata_value=-9)
emean= gr.GeoRaster(emean, growperiod.geot, projection=growperiod.projection, nodata_value=-9)
esum.to_tiff('./data/post1500TotalCalories')
emean.to_tiff('./data/post1500AverageCalories')
post1500mean = gr.from_file('./data/post1500AverageCalories.tif')
post1500tot = gr.from_file('./data/post1500TotalCalories.tif')

# %% [markdown]
# ### Drop zeroes

# %%
emat0=np.ma.masked_array(emat.data,mask=(emat.data<=0), fill_value=-9.)
esum0=emat0.sum(axis=0)
emean0=emat0.mean(axis=0)

# %%
esum0= gr.GeoRaster(esum0, growperiod.geot, projection=growperiod.projection, nodata_value=-9)
emean0= gr.GeoRaster(emean0, growperiod.geot, projection=growperiod.projection, nodata_value=-9)
esum0.to_tiff('./data/post1500TotalCaloriesNo0')
emean0.to_tiff('./data/post1500AverageCaloriesNo0')
post1500mean0 = gr.from_file('./data/post1500AverageCaloriesNo0.tif')
post1500tot0 = gr.from_file('./data/post1500TotalCaloriesNo0.tif')

# %%
post1500mean.plot()

# %%
post1500mean0.plot()
post1500tot.plot()
post1500tot0.plot()

# %% [markdown]
# ## Compute Optimal Caloric content

# %%
eopt=emat.max(axis=0)
eopt0=emat0.max(axis=0)
eopt= gr.GeoRaster(eopt, growperiod.geot, projection=growperiod.projection, nodata_value=-9)
eopt0= gr.GeoRaster(eopt0, growperiod.geot, projection=growperiod.projection, nodata_value=-9)
eopt.to_tiff('./data/post1500OptCalories')
eopt0.to_tiff('./data/post1500OptCaloriesNo0')

# %%
post1500opt=gr.from_file('./data/post1500OptCalories.tif')
post1500opt0=gr.from_file('./data/post1500OptCaloriesNo0.tif')

# %%
df=pre1500opt0.to_pandas()
# Out:
# 19454.5

# %% [markdown]
# ## Pre 1500 CE

# %%
ax = plt.matshow(esum)
mplleaflet.display(fig=ax.figure)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-22-503973e50088> in <module>()
#       1 ax = plt.matshow(esum)
# ----> 2 mplleaflet.display(fig=ax.figure)
#
# /usr/local/lib/python2.7/site-packages/mplleaflet/_display.pyc in display(fig, closefig, **kwargs)
#     140         plt.close(fig)
#     141
# --> 142     html = fig_to_html(fig, template="ipynb.html", **kwargs)
#     143     return HTML(html)
#     144
#
# /usr/local/lib/python2.7/site-packages/mplleaflet/_display.pyc in fig_to_html(fig, template, tiles, crs, epsg)
#      72     renderer = LeafletRenderer(crs=crs, epsg=epsg)
#      73     exporter = Exporter(renderer)
# ---> 74     exporter.run(fig)
#      75
#      76     attribution = _attribution + ' | ' + tiles[1]
#
# /usr/local/lib/python2.7/site-packages/mplexporter/exporter.pyc in run(self, fig)
# ...
